# %%
#https://towardsdatascience.com/implementing-different-activation-functions-and-weight-initialization-methods-using-python-c78643b9f20f
#https://medium.com/ai%C2%B3-theory-practice-business/a-beginners-guide-to-numpy-with-sigmoid-relu-and-softmax-activation-functions-25b840a9a272

import numpy as np
import random

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_d(x):
    return np.exp(-x) / ((1 + np.exp(-x)) ** 2)

def full_connected_layer(x, w, b):
    return w * x + b

def full_connected_layer_d_w(x, w, b):
    return x

def full_connected_layer_d_b(x, w, b):
    return 1

def full_connected_layer_d_x(x, w, b):
    return w


input_x_n = 6 #training data size
input_x_p = 4

x = np.array([[0.01 * (i + j) for i in range(input_x_p)] for j in range(input_x_n)])
#y = np.array([3 for i in range(input_x_n)])
y = np.array([0, 0, 1, 1, 0, 1])

input_layer_size = input_x_p
layer_1_size = 10
layer_2_size = 6
output_size = 1

#layer_size = [1, input_layer_size, layer_1_size, layer_2_size, output_size]

layer_size = [input_layer_size, layer_1_size, layer_2_size, output_size]

w = []
b = []
layer_input = [x] #rename into layer_input

#reshape might be faster than 2 level of loop way to create an array

for k in range(len(layer_size)):
    if k == 0:
        weight_in = 1
    else:
        weight_in = layer_size[k - 1]
    weight_out = layer_size[k]
    w.append(np.array([[0.12 for i in range(weight_out)] for j in range(weight_in)]))
    b.append(np.array([[0.1 for i in range(weight_out)] for j in range(weight_in)]))
    layer_input.append(np.array([[0.0 for i in range(weight_out)] for j in range(input_x_n)]))
    
#w_layer_1 = [[0] for i in arange()]
#print(w)

w[0]
layer_input
w
# Out:
# [array([[0.12, 0.12, 0.12, 0.12]]),
#  array([[0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12]]),
#  array([[0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12],
#         [0.12, 0.12, 0.12, 0.12, 0.12, 0.12]]),
#  array([[0.12],
#         [0.12],
#         [0.12],
#         [0.12],
#         [0.12],
#         [0.12]])]

# %%
def array_expand(arr, k):
    arr_y = [[[arr[j, r] for i in range(k)] for r in range(arr.shape[1])] for j in range(arr.shape[0])]
    return np.array(arr_y)

arr = np.array([[0.01 * (i + j) for i in range(input_x_p)] for j in range(input_x_n)])
#print(arr.shape[0])
print(arr.shape)
arr = array_expand(arr, 10)
print(arr.shape)

def array_club(arr):
    arr_y = [[sum(arr[j, :, i]) for i in range(arr.shape[2])]for j in range(arr.shape[0])]
    return np.array(arr_y)

arr = np.array([[[0.01 * (i + j) for i in range(input_x_p)] for j in range(input_x_n)] for n in range(12)])
print(arr.shape)
arr_y = array_club(arr)
print(arr_y.shape)
# Out:
# (6, 4)
# (6, 4, 10)
# (12, 6, 4)
# (12, 4)

# %%
"""


#input_value = []
#input_value.append(x)

current_layer_no = 0
#layer_input[0] = x

input = layer_input[0]
layer_mid_value_y[0] = np.array([[0.0 for i in range(layer_size[0])] for j in range(input_x_n)])
#print(layer_mid_value_y[0])
#print(w[0])
#print(b[0])
for column_no in range(layer_size[0]):
    layer_mid_value_y[current_layer_no][:, column_no] = input[:, column_no] * w[current_layer_no][0, column_no] + b[current_layer_no][0, column_no]

print(layer_mid_value_y[0])
sigmoid_input[0] = layer_mid_value_y[0]
sigmoid_output[0] = sigmoid(sigmoid_input[0])
layer_input[1] = sigmoid_output[0]
print("sdf")
print(layer_input[1])

"""
# Out:
# '\n\n\n#input_value = []\n#input_value.append(x)\n\ncurrent_layer_no = 0\n#layer_input[0] = x\n\ninput = layer_input[0]\nlayer_mid_value_y[0] = np.array([[0.0 for i in range(layer_size[0])] for j in range(input_x_n)])\n#print(layer_mid_value_y[0])\n#print(w[0])\n#print(b[0])\nfor column_no in range(layer_size[0]):\n    layer_mid_value_y[current_layer_no][:, column_no] = input[:, column_no] * w[current_layer_no][0, column_no] + b[current_layer_no][0, column_no]\n\nprint(layer_mid_value_y[0])\nsigmoid_input[0] = layer_mid_value_y[0]\nsigmoid_output[0] = sigmoid(sigmoid_input[0])\nlayer_input[1] = sigmoid_output[0]\nprint("sdf")\nprint(layer_input[1])\n\n'

# %%
lay_input_split = [[] for i in range(4)]
layer_mid_value_y = [[] for i in range(4)]
layer_mid_value_y_total = [[] for i in range(4)]
sigmoid_input = [[] for i in range(4)]
sigmoid_output = [[] for i in range(4)]



#print(layer_mid_value_y)
#len(layer_size)
for current_layer_no in range (0, 4):
    #print(current_layer_no)
    input = layer_input[current_layer_no]
    
    #print(lay_input_split[current_layer_no].shape)
    if current_layer_no == 0:
        last_layer_size = 1
        lay_input_split[current_layer_no] = layer_input[current_layer_no].reshape(input_x_n, 1, input_x_p)
    else:
        lay_input_split[current_layer_no] = array_expand(layer_input[current_layer_no], layer_size[current_layer_no])
        last_layer_size = layer_size[current_layer_no - 1]
    layer_mid_value_y[current_layer_no] = np.array([[[0.0 for r in range(layer_size[current_layer_no])] for i in range(last_layer_size)] for j in range(input_x_n)])
    
    for case_no in range(input_x_n):
        layer_mid_value_y[current_layer_no][case_no] = lay_input_split[current_layer_no][case_no] * w[current_layer_no] + b[current_layer_no]
    
    layer_mid_value_y_total[current_layer_no] = array_club(layer_mid_value_y[current_layer_no])
    
    """
    for row_no in range(layer_size[current_layer_no - 1]):
        for column_no in range(layer_size[current_layer_no]):
            layer_mid_value_y[current_layer_no][:, row_no, column_no] = input[:, row_no] * w[current_layer_no][row_no, column_no] + b[current_layer_no][row_no, column_no]
    #layer_input.append(np.array([[0.0 for i in range(layer_size[current_layer_no + 1])] for j in range(input_x_n)]))
    for m in range(layer_size[current_layer_no]):
        for k in range(input_x_n):
            #print(m)
            layer_input[current_layer_no + 1][k, m] = sum(layer_mid_value_y[current_layer_no][k, :, m])
    """
    
    
    sigmoid_input[current_layer_no] = layer_mid_value_y_total[current_layer_no]
    sigmoid_output[current_layer_no] = sigmoid(sigmoid_input[current_layer_no])
    layer_input[current_layer_no + 1] = sigmoid_output[current_layer_no]
print(layer_input)

#print(layer_size[2])
#print(layer_mid_value_y[1][0, :, 9])
#print("dfs")
#print(layer_mid_value_y)


#print(layer_input[1][0])



        
"""
things needed for DL training:
weight dict:
    input
    each layer
    output
bais dict:
    input
    each layer
    output

during training:
    each layer input & output - TBC
    current w & b value
    

how to add a for loop to calculate parameter of w & b

2 hours to finish it

"""


"""
current_layer_no = 2
input = layer_mid_value_y[1]
layer_mid_value_y.append(np.array([[0.0 for i in range(layer_size[3])] for j in range(n)]))
for column_no in range(layer_size[3]):
    layer_mid_value_y[current_layer_no][:, column_no] = input[:, column_no] * w[current_layer_no][column_no] + b[current_layer_no][column_no]

"""
# Out:
# [array([[0.  , 0.01, 0.02, 0.03],
#        [0.01, 0.02, 0.03, 0.04],
#        [0.02, 0.03, 0.04, 0.05],
#        [0.03, 0.04, 0.05, 0.06],
#        [0.04, 0.05, 0.06, 0.07],
#        [0.05, 0.06, 0.07, 0.08]]), array([[0.52497919, 0.52527843, 0.52557765, 0.52587686],
#        [0.52527843, 0.52557765, 0.52587686, 0.52617605],
#        [0.52557765, 0.52587686, 0.52617605, 0.52647522],
#        [0.52587686, 0.52617605, 0.52647522, 0.52677436],
#        [0.52617605, 0.52647522, 0.52677436, 0.52707349],
#        [0.52647522, 0.52677436, 0.52707349, 0.52737261]]), array([[0.65750728, 0.65750728, 0.65750728, 0.65750728, 0.65750728,
#         0.65750728, 0.65750728, 0.65750728, 0.65750728, 0.65750728],
#        [0.65753963, 0.65753963, 0.65753963, 0.65753963, 0.65753963,
#         0.65753963, 0.65753963, 0.65753963, 0.65753963, 0.65753963],
#        [0.65757197, 0.65757197, 0.65757197, 0.65757197, 0.65757197,
#         0.65757197, 0.65757197, 0.65757197, 0.65757197, 0.65757197],
#        [0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 ,
#         0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 ],
#        [0.65763663, 0.65763663, 0.65763663, 0.65763663, 0.65763663,
#         0.65763663, 0.65763663, 0.65763663, 0.65763663, 0.65763663],
#        [0.65766896, 0.65766896, 0.65766896, 0.65766896, 0.65766896,
#         0.65766896, 0.65766896, 0.65766896, 0.65766896, 0.65766896]]), array([[0.8568057 , 0.8568057 , 0.8568057 , 0.8568057 , 0.8568057 ,
#         0.8568057 ],
#        [0.85681046, 0.85681046, 0.85681046, 0.85681046, 0.85681046,
#         0.85681046],
#        [0.85681522, 0.85681522, 0.85681522, 0.85681522, 0.85681522,
#         0.85681522],
#        [0.85681999, 0.85681999, 0.85681999, 0.85681999, 0.85681999,
#         0.85681999],
#        [0.85682474, 0.85682474, 0.85682474, 0.85682474, 0.85682474,
#         0.85682474],
#        [0.8568295 , 0.8568295 , 0.8568295 , 0.8568295 , 0.8568295 ,
#         0.8568295 ]]), array([[0.77151757],
#        [0.77151817],
#        [0.77151877],
#        [0.77151938],
#        [0.77151998],
#        [0.77152059]])]
# '\ncurrent_layer_no = 2\ninput = layer_mid_value_y[1]\nlayer_mid_value_y.append(np.array([[0.0 for i in range(layer_size[3])] for j in range(n)]))\nfor column_no in range(layer_size[3]):\n    layer_mid_value_y[current_layer_no][:, column_no] = input[:, column_no] * w[current_layer_no][column_no] + b[current_layer_no][column_no]\n\n'

# %%
layer_input
#lay_input_split
#layer_mid_value_y
#layer_mid_value_y_total
#sigmoid_input
#sigmoid_output
# Out:
# [array([[0.  , 0.01, 0.02, 0.03],
#         [0.01, 0.02, 0.03, 0.04],
#         [0.02, 0.03, 0.04, 0.05],
#         [0.03, 0.04, 0.05, 0.06],
#         [0.04, 0.05, 0.06, 0.07],
#         [0.05, 0.06, 0.07, 0.08]]),
#  array([[0.52497919, 0.52527843, 0.52557765, 0.52587686],
#         [0.52527843, 0.52557765, 0.52587686, 0.52617605],
#         [0.52557765, 0.52587686, 0.52617605, 0.52647522],
#         [0.52587686, 0.52617605, 0.52647522, 0.52677436],
#         [0.52617605, 0.52647522, 0.52677436, 0.52707349],
#         [0.52647522, 0.52677436, 0.52707349, 0.52737261]]),
#  array([[0.65750728, 0.65750728, 0.65750728, 0.65750728, 0.65750728,
#          0.65750728, 0.65750728, 0.65750728, 0.65750728, 0.65750728],
#         [0.65753963, 0.65753963, 0.65753963, 0.65753963, 0.65753963,
#          0.65753963, 0.65753963, 0.65753963, 0.65753963, 0.65753963],
#         [0.65757197, 0.65757197, 0.65757197, 0.65757197, 0.65757197,
#          0.65757197, 0.65757197, 0.65757197, 0.65757197, 0.65757197],
#         [0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 ,
#          0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 , 0.6576043 ],
#         [0.65763663, 0.65763663, 0.65763663, 0.65763663, 0.65763663,
#          0.65763663, 0.65763663, 0.65763663, 0.65763663, 0.65763663],
#         [0.65766896, 0.65766896, 0.65766896, 0.65766896, 0.65766896,
#          0.65766896, 0.65766896, 0.65766896, 0.65766896, 0.65766896]]),
#  array([[0.8568057 , 0.8568057 , 0.8568057 , 0.8568057 , 0.8568057 ,
#          0.8568057 ],
#         [0.85681046, 0.85681046, 0.85681046, 0.85681046, 0.85681046,
#          0.85681046],
#         [0.85681522, 0.85681522, 0.85681522, 0.85681522, 0.85681522,
#          0.85681522],
#         [0.85681999, 0.85681999, 0.85681999, 0.85681999, 0.85681999,
#          0.85681999],
#         [0.85682474, 0.85682474, 0.85682474, 0.85682474, 0.85682474,
#          0.85682474],
#         [0.8568295 , 0.8568295 , 0.8568295 , 0.8568295 , 0.8568295 ,
#          0.8568295 ]]),
#  array([[0.77151757],
#         [0.77151817],
#         [0.77151877],
#         [0.77151938],
#         [0.77151998],
#         [0.77152059]])]

# %%
b_parameter = [[] for i in range(4)]
w_parameter = [[] for i in range(4)]

target = y.reshape(6, 1)
output = layer_input[4]
target

mid_value = 2 * (target - output)

"""
current_layer = 3
mid_value = mid_value / layer_input[current_layer + 1]

mid_value *= sigmoid_d(sigmoid_input[current_layer])
#mid_value = mid_value
b_parameter[current_layer] = mid_value
w_parameter[current_layer] = layer_input[current_layer] * mid_value
"""


for current_layer in range(3, 0, -1):
    #print(current_layer)
    #print(mid_value)
    if current_layer < 3:
        mid_value *= w[current_layer + 1]
    #print(mid_value)
    mid_value = mid_value / layer_input[current_layer + 1]
    
    mid_value_2 = []
    
    for i in range(6):
        mid_value_2.append(np.array(layer_mid_value_y[current_layer][i]).dot(np.array(mid_value[i])))
    mid_value = mid_value_2
    #mid_value = np.array(layer_mid_value_y[current_layer]).dot(np.array(mid_value))
    mid_value *= sigmoid_d(sigmoid_input[current_layer])
    
    
    b_parameter[current_layer] = mid_value
    w_parameter[current_layer] = layer_input[current_layer] * mid_value


b_parameter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-133042a4f44a> in <module>
#      37
#      38     b_parameter[current_layer] = mid_value
# ---> 39     w_parameter[current_layer] = layer_input[current_layer] * mid_value
#      40
#      41
#
# ValueError: operands could not be broadcast together with shapes (6,10) (6,10,6)

# %%
b_parameter
# Out:
# [[],
#  [],
#  array([[[-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557],
#          [-0.00176557, -0.00176557, -0.00176557, -0.00176557,
#           -0.00176557, -0.00176557]],
#
#         [[-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561],
#          [-0.00176561, -0.00176561, -0.00176561, -0.00176561,
#           -0.00176561, -0.00176561]],
#
#         [[-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565],
#          [-0.00176565, -0.00176565, -0.00176565, -0.00176565,
#           -0.00176565, -0.00176565]],
#
#         [[-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568],
#          [-0.00176568, -0.00176568, -0.00176568, -0.00176568,
#           -0.00176568, -0.00176568]],
#
#         [[-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572],
#          [-0.00176572, -0.00176572, -0.00176572, -0.00176572,
#           -0.00176572, -0.00176572]],
#
#         [[-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576],
#          [-0.00176576, -0.00176576, -0.00176576, -0.00176576,
#           -0.00176576, -0.00176576]]]),
#  array([[-0.03264042],
#         [-0.03264038],
#         [ 0.00966627],
#         [ 0.00966622],
#         [-0.03264028],
#         [ 0.00966614]])]

# %%
-0.27200347 * 0.8568057
0.85681522 * 0.08055222
# Out:
# 0.06901836810078839

# %%
w_4_parameter
# Out:
# array([[-0.23305413, -0.23305413, -0.23305413, -0.23305413, -0.23305413,
#         -0.23305413],
#        [-0.23305517, -0.23305517, -0.23305517, -0.23305517, -0.23305517,
#         -0.23305517],
#        [ 0.06901837,  0.06901837,  0.06901837,  0.06901837,  0.06901837,
#          0.06901837],
#        [ 0.06901844,  0.06901844,  0.06901844,  0.06901844,  0.06901844,
#          0.06901844],
#        [-0.2330583 , -0.2330583 , -0.2330583 , -0.2330583 , -0.2330583 ,
#         -0.2330583 ],
#        [ 0.06901859,  0.06901859,  0.06901859,  0.06901859,  0.06901859,
#          0.06901859]])

# %%
layer_input[3]
# Out:
# array([[0.8568057 , 0.8568057 , 0.8568057 , 0.8568057 , 0.8568057 ,
#         0.8568057 ],
#        [0.85681046, 0.85681046, 0.85681046, 0.85681046, 0.85681046,
#         0.85681046],
#        [0.85681522, 0.85681522, 0.85681522, 0.85681522, 0.85681522,
#         0.85681522],
#        [0.85681999, 0.85681999, 0.85681999, 0.85681999, 0.85681999,
#         0.85681999],
#        [0.85682474, 0.85682474, 0.85682474, 0.85682474, 0.85682474,
#         0.85682474],
#        [0.8568295 , 0.8568295 , 0.8568295 , 0.8568295 , 0.8568295 ,
#         0.8568295 ]])
